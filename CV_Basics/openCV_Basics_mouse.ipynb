# %% [markdown]
# # mouse click

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt



##############################
## Function##
##############################

# here x and y define the mouse positions
# here event fedine mouse click 
def draw_circle(event,x,y,flags,param):
    if event == cv2.EVENT_LBUTTONDOWN:
        cv2.circle(img,(x,y),100,(0,255,0),-1)
        
    elif event == cv2.EVENT_RBUTTONDOWN:
        # BGR
        cv2.circle(img,(x,y),50,(255,0,0),-1)

cv2.namedWindow(winname='mydrawing')

cv2.setMouseCallback('mydrawing',draw_circle)






##############################
## Show the Image with opencv ##
##############################


img  = np.zeros((512,512,3))
# plt.imshow(img)

while True: 
    cv2.imshow('mydrawing',img)
    if cv2.waitKey(20) & 0xff ==27:
        break
cv2.destroyAllWindows()

# %% [markdown]
# # Mouse Drag

# %%
import cv2 
import numpy as np


# variables 
# here this drawing variables becomes true if the mouse has been pressed 
# True if the mouse button down and false of the mouse button up 
# 
drawing  = False
ix,iy = -1,-1





# function 
def draw_rectangle(event,x,y,flags,params):
    global ix,iy,drawing
    
    if event == cv2.EVENT_LBUTTONDOWN:
        drawing = True
        ix,iy = x,y
        
    elif event == cv2.EVENT_MOUSEMOVE:
        if drawing == True:
            cv2.rectangle(img,(ix,iy),(x,y),(0,255,0),-1)
    
    elif event == cv2.EVENT_LBUTTONUP:
        drawing = False
        cv2.rectangle(img,(ix,iy),(x,y),(0,255,0),-1)


# showing the image 

# Black 
img  = np.zeros((512,512,3))

cv2.namedWindow(winname='Draw')
cv2.setMouseCallback('Draw',draw_rectangle)

while True :
    cv2.imshow('Draw',img)
    if cv2.waitKey(1) & 0xFF == 27 :
        break
cv2.destroyAllWindows()

# %% [markdown]
# # Test

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
img  = cv2.imread('DATA/dog_backpack.png')
plt.imshow(img)

# %%
img_rgb = cv2.cvtColor(img,cv2.COLOR_BGR2RGB)
plt.imshow(img_rgb)

# %%
flip_img  = img_rgb.copy()

# %%
flip_img = cv2.flip(flip_img,0)
plt.imshow(flip_img)

# %%
pt1 = (200,380)
pt2 = (600,700)

# %%
rect  = cv2.rectangle(img_rgb,pt1=pt1,pt2=pt2,color=(255,0,0),thickness=5)
plt.imshow(rect)

# %%
# to draw a triangle 
# pick the 3 vertices
vertices = np.array([ [250,700],[400,400],[600,700] ],np.int32 )
vertices
# Out:
# array([[250, 700],
#        [400, 400],
#        [600, 700]], dtype=int32)

# %%
vertices.shape
# Out:
# (3, 2)

# %%
pts = vertices.reshape((-1,1,2))

# %%
vertices
# Out:
# array([[250, 700],
#        [400, 400],
#        [600, 700]], dtype=int32)

# %%
pts.shape
# Out:
# (3, 1, 2)

# %%
Tri = cv2.polylines(img_rgb,[pts],isClosed=True,color=(0,0,255),thickness=20)
plt.imshow(Tri)

# %%
#

# %%
# Python: cv2.fillPoly(img, pts, color[, lineType[, shift[, offset]]]) → img
#  
Tri_fill = cv2.fillPoly(img_rgb,[pts],color=(0,0,255))
plt.imshow(Tri_fill)

# %%
#

# %%
# draw red circle for right click

# %%
def create_Circle(event,x,y,flags,param):
    if event == cv2.EVENT_RBUTTONDOWN:
        cv2.circle(img,(x,y),50,(0,0,255),thickness=10)

        
img = cv2.imread('DATA/dog_backpack.png')
cv2.namedWindow(winname='dog')
cv2.setMouseCallback('dog',create_Circle)

while True :
    cv2.imshow('dog',img )
    if cv2.waitKey(20) & 0xFF == 27:
        break
cv2.destroyAllWindows()
